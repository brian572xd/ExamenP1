# %% [markdown]
# <a href="https://colab.research.google.com/github/brian572xd/ExamenP1/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Examen parcial 1

# %% [markdown]
# Problema práctico de cálculo de RMSE: Se te dan los valores observados y predichos de una variable numérica para 4 observaciones: observados = [3, 7, 5, 10], predichos = [2, 8, 4, 9]. Calcula el RMSE

# %% [markdown]
# Respuesta
#
# primero se resta cada valor observado a cada valor predicho, se eleva al cuadrado y se calcula el promedio para el ultimo paso que es sacar su raiz cuadrada

# %%
import numpy as np

observados = np.array([3, 7, 5, 10])
predichos = np.array([2, 8, 4, 9])

resta = observados - predichos

resta
# Out:
# array([ 1, -1,  1,  1])

# %%
errores = np.array([1, -1, 1, 1])
cuadrados = errores ** 2

cuadrados = np.square(errores)

cuadrados
# Out:
# array([1, 1, 1, 1])

# %% [markdown]
# dividimos entre 4 y sacamos su raiz cuadrada pero al ser todos 1 el resultado sera 1

# %% [markdown]
# Problema de probabilidad condicional
# En una fábrica se producen piezas mediante dos máquinas, A y B.
#
# La máquina A produce el 60% del total de las piezas.
# La máquina B produce el 40% restante.
# Sin embargo, no son igual de precisas:
#
# La máquina A produce 2% de piezas defectuosas.
# La máquina B produce 5% de piezas defectuosas.
# Un inspector toma una pieza al azar del inventario general y encuentra que la pieza está defectuosa.
#
# Pregunta:
#
# ¿Cuál es la probabilidad de que la pieza haya sido fabricada por la máquina B?

# %% [markdown]
# $P(A) = 0.60$ (Probabilidad de que sea de la máquina A)
# $P(B) = 0.40$ (Probabilidad de que sea de la máquina B)
# $P(D|A) = 0.02$ (Probabilidad de defecto dado que es de A)
# $P(D|B) = 0.05$ (Probabilidad de defecto dado que es de B)

# %% [markdown]
# $$P(D) = (0.60 \cdot 0.02) + (0.40 \cdot 0.05)$$
# $$P(D) = 0.012 + 0.020 = \mathbf{0.032}$$

# %% [markdown]
# Ahora calculamos la probabilidad de que, dado que ya sabemos que la pieza es defectuosa ($D$), esta provenga de la máquina B:
#
#
# $$P(B|D) = \frac{P(B) \cdot P(D|B)}{P(D)}$$Sustituimos los valores:
#
# $$P(B|D) = \frac{0.40 \cdot 0.05}{0.032}$$
# $$P(B|D) = \frac{0.020}{0.032}$$
# $$P(B|D) = 0.625$$

# %% [markdown]
# Acontinuación se te presenta una simulación de un caso en el que se pretende determinar si el consumo de café por los estudiantes ayuda a estudiar.
#
# Imagina que seleccionas a 20 estudiantes al azar. A 10 les das café y a otros 10 les das agua, luegos les pides que resuelvan un examen de lógica.

# %%
import pandas as pd
import numpy as np


# Establece una semilla para reproducibilidad
np.random.seed(42)


# 1. Crea una lista de matrículas de estudiantes
student_ids = [f'{i:06d}' for i in range(172120, 172120 + 20)]


# 2. Asigna 10 estudiantes al grupo 'Café' y 10 al grupo 'Agua'
groups = ['Café'] * 10 + ['Agua'] * 10
np.random.shuffle(groups)


# 3. Simula calificacionen de examenes para el grupo café
# Mean=70, Std=5, asegurate de que los valores estén entre (50-100)
coffee_scores = np.random.normal(loc=70, scale=5, size=10).round(0)
coffee_scores = np.clip(coffee_scores, 50, 100).astype(int)


# 4. Simula calificaciones de examen para el grupo de 'Agua'
# Mean=75, Std=5, asegurate de que los valores estén entre (50-100)
water_scores = np.random.normal(loc=75, scale=5, size=10).round(0)
water_scores = np.clip(water_scores, 50, 100).astype(int)


# Combina los valores basado en el grupo
exam_scores = []
coffee_idx = 0
water_idx = 0
for group in groups:
    if group == 'Café':
        exam_scores.append(coffee_scores[coffee_idx])
        coffee_idx += 1
    else:
        exam_scores.append(water_scores[water_idx])
        water_idx += 1


# 5. Combina en un DataFrame de Pandas
df_students = pd.DataFrame({
    'Matrícula': student_ids,
    'Grupo': groups,
    'Calificaciones': exam_scores
})


print("Datos simulados:")
print(df_students.head())
# Out:
# Datos simulados:
#   Matrícula Grupo  Calificaciones
# 0    172120  Café              77
# 1    172121  Agua              77
# 2    172122  Agua              79
# 3    172123  Café              78
# 4    172124  Café              58

# %%
#media
comparativa = df_students.groupby('Grupo')['Calificaciones'].mean()
comparativa
# Out:
# Grupo
# Agua    74.9
# Café    70.6
# Name: Calificaciones, dtype: float64

# %% [markdown]
# Tabla de contingencia de curso vs. examen

# %% [markdown]
# Calcula la probabilidad condicional de aprobar si se tomó el curso
# A = 45 personas
#
# B = 50 personas
#
# $$ 45/50= 0.9 $$

# %% [markdown]
# De la tabla de contingencia de la pregunta anterior calcula la probabilidad simple de aprobar
#
# Total de personas que aprobaron: 65.
#
# Total de personas en el estudio: 100.
#
# $$ 65/100 = 0.65 $$

# %% [markdown]
# #Porcentaje de colores

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3cb5bfc6-d805-4a53-b896-0414d7d2a43c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3cb5bfc6-d805-4a53-b896-0414d7d2a43c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('munsell-array-fixed-choice.csv')
df
# Out:
#    grid   x  y munsell_code tile_hex english_color spanish_color  \
# 0    B1   1  7        5R8/6  #fbb6b0          pink          pink
# 1    D1   1  5       5R6/12  #eb6a68          pink          pink
# 2    F1   1  3       5R4/14  #bb1933           red           red
# 3    H1   1  1        5R2/8  #610d25           red           red
# 4    A2   2  8       10R9/2  #f2ded8          pink         white
# ..  ...  .. ..          ...      ...           ...           ...
# 75  H19  19  1       5RP2/8  #591340        purple        purple
# 76  A20  20  8      10RP9/2  #efdfe0          pink         white
# 77  C20  20  6      10RP7/8  #ea95a0          pink          pink
# 78  E20  20  4     10RP5/14  #d73f6a          pink          pink
# 79  G20  20  2     10RP3/10  #891641        purple           red
#
#    tsimane_color          spanish              tsimane
# 0         yellow    rosada (pink)      chamus (yellow)
# 1            red    rosada (pink)         jainas (red)
# ...

# %%
#For each language, calculate what percentage of chips are named each color. Return dataframes for each language.
english = df['english_color'].value_counts(normalize=True) * 100
spanish = df['spanish_color'].value_counts(normalize=True) * 100
tsimane = df['tsimane_color'].value_counts(normalize=True) * 100

# %%
#Dataframes
english_df = english.reset_index()
english_df.columns = ['Color', 'Porcentaje']
print(english_df,"\n")

spanish_df = spanish.reset_index()
spanish_df.columns = ['Color', 'Porcentaje']
print(spanish_df,"\n")

tsimane_df = tsimane.reset_index()
tsimane_df.columns = ['Color', 'Porcentaje']
print(tsimane_df)
# Out:
#     Color  Porcentaje
# 0   green       27.50
# 1    blue       20.00
# 2  purple       13.75
# 3    pink       12.50
# 4  yellow        6.25
# 5   brown        6.25
# 6  orange        5.00
# 7     red        3.75
# 8   black        2.50
# 9   white        2.50
#
#         Color  Porcentaje
# 0       green       27.50
# 1   lightblue       13.75
# 2      purple       13.75
# 3        pink       10.00
# 4       white        7.50
# 5         red        5.00
# 6      orange        5.00
# 7      yellow        5.00
# 8       brown        5.00
# 9        blue        5.00
# 10      black        2.50
#
#     Color  Porcentaje
# 0   green       25.00
# 1    blue       15.00
# 2  yellow       13.75
# 3  purple       12.50
# 4   white       11.25
# 5     red       10.00
# 6   brown        8.75
# 7   black        3.75

# %%
english_df.plot.barh(x='Color', y='Porcentaje', color ='green')
plt.xlabel('Porcentaje')
plt.ylabel('Color')
plt.title('Porcentaje de Chips por Color en Inglés')
plt.show()
print("\n")
spanish_df.plot.barh(x='Color', y='Porcentaje', color = 'purple')
plt.xlabel('Porcentaje')
plt.ylabel('Color')
plt.title('Porcentaje de Chips por Color en Español')
plt.show()
print("\n")
tsimane_df.plot.barh(x='Color', y='Porcentaje', color = 'red')
plt.xlabel('Porcentaje')
plt.ylabel('Color')
plt.title('Porcentaje de Chips por Color en Tsimane')
plt.show()

# %%
#Grafico 1
eng_spa = english_df.merge(spanish_df, on='Color')
eng_spa.columns = ['Color', 'Porcentaje_ingles', 'Porcentaje_Español']
plt.scatter(eng_spa['Porcentaje_ingles'], eng_spa['Porcentaje_Español'], color = 'Fuchsia')
plt.xlabel('Porcentaje Ingles ')
plt.ylabel('Porcentaje Español')
plt.title('Porcentaje de Chips por Color en Inglés vs Español')
plt.show()
print("\n")

#Grafico 2
eng_tsi = english_df.merge(tsimane_df, on='Color')
eng_tsi.columns = ['Color', 'Porcentaje_ingles', 'Porcentaje_Tsimane']
plt.scatter(eng_tsi['Porcentaje_ingles'], eng_tsi['Porcentaje_Tsimane'], color = 'teal')
plt.xlabel('Porcentaje Ingles ')
plt.ylabel('Porcentaje Tsimane')
plt.title('Porcentaje de Chips por Color en Inglés vs Tsimane')
plt.show()

#Grafico 3
spa_tsi = spanish_df.merge(tsimane_df, on='Color')
spa_tsi.columns = ['Color', 'Porcentaje_Español', 'Porcentaje_Tsimane']
plt.scatter(spa_tsi['Porcentaje_Español'], spa_tsi['Porcentaje_Tsimane'], color = 'orange')
plt.xlabel('Porcentaje Español ')
plt.ylabel('Porcentaje Tsimane')
plt.title('Porcentaje de Chips por Color en Español vs Tsimane')
plt.show()

# %%
spanish_df = df['spanish_color'].value_counts().reset_index()
spanish_df
# Out:
#    spanish_color  count
# 0          green     22
# 1      lightblue     11
# 2         purple     11
# 3           pink      8
# 4          white      6
# 5            red      4
# 6         orange      4
# 7         yellow      4
# 8          brown      4
# 9           blue      4
# 10         black      2

# %%
spanish_df2['sp_color_percentage'] = spanish_df2['count_es'] / spanish_df2['count_es'].sum() * 100
spanish_df2
# Out:
#    spanish_color  count_es  sp_color_percentage
# 0          green        22                27.50
# 1      lightblue        11                13.75
# 2         purple        11                13.75
# 3           pink         8                10.00
# 4          white         6                 7.50
# 5            red         4                 5.00
# 6         orange         4                 5.00
# 7         yellow         4                 5.00
# 8          brown         4                 5.00
# 9           blue         4                 5.00
# 10         black         2                 2.50

# %%
corr_ing_esp = pd.merge(english_df, spanish_df, left_on='Color', right_on='spanish_color', how='inner')
corr_ing_esp
# Out:
#     Color  Porcentaje spanish_color  count
# 0   green       27.50         green     22
# 1    blue       20.00          blue      4
# 2  purple       13.75        purple     11
# 3    pink       12.50          pink      8
# 4  yellow        6.25        yellow      4
# 5   brown        6.25         brown      4
# 6  orange        5.00        orange      4
# 7     red        3.75           red      4
# 8   black        2.50         black      2
# 9   white        2.50         white      6

# %% [markdown]
# #Examen parcial 2

# %%
#pregunta 1
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3bcd2399-8579-45e6-b33d-2d7eed020aa7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3bcd2399-8579-45e6-b33d-2d7eed020aa7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("ventas.csv", parse_dates = ["fecha"])
df = df.set_index("fecha")
print (df.head(3))
print (df.info())
# Out:
#            producto  unidades  precio_unitario
# fecha
# 2025-01-03        A        10            120.5
# 2025-01-05        B         7             98.0
# 2025-01-06        A         3            120.5
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4 entries, 2025-01-03 to 2025-01-10
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   producto         4 non-null      object
#  1   unidades         4 non-null      int64
#  2   precio_unitario  4 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 128.0+ bytes
# None

# %%
#pregunta 2
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6002d906-a9af-48a1-b219-a5aa828ded49" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6002d906-a9af-48a1-b219-a5aa828ded49">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('items.csv')
df
# Out:
#   categoria item  precio  cantidad
# 0         A    x     100         2
# 1         A    y     250         1
# 2         B    z      80         5
# 3         B    w     120         3
# 4         A    k     200         2

# %%
df.eval('importe = precio * cantidad', inplace=True)
dfa = df.query("categoria == 'importe'")
promedio = df.groupby('categoria')['importe'].mean()
promedio
# Out:
# categoria
# A    283.333333
# B    380.000000
# Name: importe, dtype: float64

# %%
#pregunta 3
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cce9af5f-b1c1-41a5-8a4b-9b1deda36a6d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cce9af5f-b1c1-41a5-8a4b-9b1deda36a6d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
dfc = pd.read_csv('clientes.csv')
dfo = pd.read_csv('ordenes.csv')
df_merged = pd.merge(dfc, dfo, on='cliente_id', how='left')
total_filas = len(df_merged)
print(f"Número total de filas del left merge: {total_filas}")
df_merged['monto'] = df_merged['monto'].fillna(0)
monto_por_cliente = df_merged.groupby('cliente_id')['monto'].sum().reset_index()
print("\nMonto total por cliente:")
print(monto_por_cliente)
monto_cliente_1 = monto_por_cliente.loc[monto_por_cliente['cliente_id'] == 1, 'monto'].values
if len(monto_cliente_1) > 0:
    print(f"\nEl monto total para el cliente_id=1 es: {monto_cliente_1[0]}")
else:
    print("\nEl cliente_id=1 no se encuentra en los datos.")
# Out:
# Número total de filas del left merge: 5
#
# Monto total por cliente:
#    cliente_id  monto
# 0           1  450.0
# 1           2    0.0
# 2           3  200.0
# 3           4    0.0
#
# El monto total para el cliente_id=1 es: 450.0

# %%
#pregunta 4
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f68173d4-9c26-4e32-b856-5138aa08523e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f68173d4-9c26-4e32-b856-5138aa08523e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("sensores.csv", usecols=["ts", "temperatura", "humedad"])
df["ts"] = pd.to_datetime(df["ts"], format="mixed", errors="coerce")
mediana_temp = df["temperatura"].median()
df["temperatura"] = df["temperatura"].fillna(mediana_temp)

media_hum = df["humedad"].mean()
df["humedad"] = df["humedad"].fillna(media_hum)

nat_count = df["ts"].isna().sum()
final_mediana_temp = round(df["temperatura"].median(), 1)
final_media_hum = round(df["humedad"].mean(), 3)

print("NaT en ts:", nat_count)
print("Mediana temperatura:", final_mediana_temp)
print("Media humedad:", final_media_hum)
# Out:
# NaT en ts: 0
# Mediana temperatura: 22.8
# Media humedad: 46.167
